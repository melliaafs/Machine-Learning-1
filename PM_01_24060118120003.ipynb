# %% [markdown]
# <a href="https://colab.research.google.com/github/melliaafs/Machine-Learning-1/blob/main/PM_01_24060118120003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mellia Arya Firannur Sukma
# 24060118120003
# Praktikum Machine Learning C2 ke-1
# Summary Dataset

# %%
url ="https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data"

# %%
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']

# %%
import pandas
dataset = pandas.read_csv(url, names=names)

# %%
print(dataset.shape)
# Out:
# (699, 5)

# %%
print(dataset.head(20))
# Out:
#                       sepal-length  sepal-width  petal-length  petal-width  \
# 1000025 5  1  1  1  2            1            3             1            1
# 1002945 5  4  4  5  7           10            3             2            1
# 1015425 3  1  1  1  2            2            3             1            1
# 1016277 6  8  8  1  3            4            3             7            1
# 1017023 4  1  1  3  2            1            3             1            1
# 1017122 8  10 10 8  7           10            9             7            1
# 1018099 1  1  1  1  2           10            3             1            1
# 1018561 2  1  2  1  2            1            3             1            1
# 1033078 2  1  1  1  2            1            1             1            5
#         4  2  1  1  2            1            2             1            1
# 1035283 1  1  1  1  1            1            3             1            1
# ...

# %%
print(dataset.groupby('class').size())
# Out:
# class
# 2    458
# 4    241
# dtype: int64

# %%
print(dataset.describe())
# Out:
#        sepal-width  petal-length  petal-width       class
# count   699.000000    699.000000   699.000000  699.000000
# mean      3.437768      2.866953     1.589413    2.689557
# std       2.438364      3.053634     1.715078    0.951273
# min       1.000000      1.000000     1.000000    2.000000
# 25%       2.000000      1.000000     1.000000    2.000000
# 50%       3.000000      1.000000     1.000000    2.000000
# 75%       5.000000      4.000000     1.000000    4.000000
# max      10.000000     10.000000    10.000000    4.000000

# %%
import matplotlib.pyplot as plt

# %%
dataset.plot(kind='box',subplots=True, layout=(2,2), sharex= False)
plt.show()

# %%
dataset.hist()
plt.show()

# %%
import pandas 
from pandas.plotting import scatter_matrix
scatter_matrix(dataset)
plt.show()
